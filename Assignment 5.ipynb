# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Store filepaths in variables
city_data="city_data.csv"
ride_data="ride_data.csv"

# %%
# Open files as Dataframes using pandas library reader module
city_df=pd.read_csv(city_data)
city_df.head()
# Out:
#              city  driver_count   type
# 0      Kelseyland            63  Urban
# 1      Nguyenbury             8  Urban
# 2    East Douglas            12  Urban
# 3   West Dawnfurt            34  Urban
# 4  Rodriguezburgh            52  Urban

# %%
# Open files as Dataframes using pandas library reader module
ride_df=pd.read_csv(ride_data)
ride_df.head()
# Out:
#           city                 date   fare        ride_id
# 0     Sarabury  2016-01-16 13:49:27  38.35  5403689035038
# 1    South Roy  2016-01-02 18:42:34  17.49  4036272335942
# 2  Wiseborough  2016-01-21 17:35:29  44.18  3645042422587
# 3  Spencertown  2016-07-31 14:53:22   6.87  2242596575892
# 4   Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673

# %%
Data_Merge=pd.merge(city_df, ride_df, on="city", how="outer")
Transport_1=Data_Merge.rename(columns={"city":"City", "driver_count":"Drivers", "type":"Type","date":"Date","fare":"Fare", "ride_id":"Ride_ID"})
Transport_1.head()
# Out:
#          City  Drivers   Type                 Date   Fare        Ride_ID
# 0  Kelseyland       63  Urban  2016-08-19 04:27:52   5.51  6246006544795
# 1  Kelseyland       63  Urban  2016-04-17 06:59:50   5.54  7466473222333
# 2  Kelseyland       63  Urban  2016-05-04 15:06:07  30.54  2140501382736
# 3  Kelseyland       63  Urban  2016-01-25 20:44:56  12.08  1896987891309
# 4  Kelseyland       63  Urban  2016-08-09 18:19:47  17.91  8784212854829

# %%
# Finding Total Number of Rides Per City
Total_number_rides_per_city=Data_Merge["city"].value_counts()
Total_number_rides_per_city
# Out:
# Port James              64
# Swansonbury             34
# Port Johnstad           34
# South Louis             32
# Alvarezhaven            31
# Jacobfort               31
# Arnoldview              31
# West Peter              31
# Williamshire            31
# Stewartview             30
# West Brandy             30
# Carrollfort             29
# West Oscar              29
# West Dawnfurt           29
# New David               28
# Lisaville               28
# New Andreamouth         28
# Kelseyland              28
# East Erin               28
# Kimberlychester         27
# Sandymouth              27
# Sarabury                27
# Port Samantha           27
# Smithhaven              27
# Edwardsbury             27
# Torresshire             26
# Alyssaberg              26
# Spencertown             26
# Nguyenbury              26
# New Jeffrey             25
#                         ..
# South Joseph            12
# Jasonfort               12
# Clarkstad               12
# ...

# %%
# Finding Average Fare per City 
Data_Index_Change=Data_Merge.set_index("city")
print(Data_Index_Change)
List_Towns=Data_Index_Change.index.tolist()
print(List_Towns)
# Out:
#                 driver_count   type                 date   fare        ride_id
# city
# Kelseyland                63  Urban  2016-08-19 04:27:52   5.51  6246006544795
# Kelseyland                63  Urban  2016-04-17 06:59:50   5.54  7466473222333
# Kelseyland                63  Urban  2016-05-04 15:06:07  30.54  2140501382736
# Kelseyland                63  Urban  2016-01-25 20:44:56  12.08  1896987891309
# Kelseyland                63  Urban  2016-08-09 18:19:47  17.91  8784212854829
# Kelseyland                63  Urban  2016-10-24 15:15:46  33.56  4797969661996
# Kelseyland                63  Urban  2016-06-06 13:54:23  20.81  9811478565448
# Kelseyland                63  Urban  2016-08-10 07:02:40  44.53  1563171128434
# Kelseyland                63  Urban  2016-07-05 17:37:13  29.02  6897992353955
# Kelseyland                63  Urban  2016-04-25 02:18:31  20.05  1148374505062
# Kelseyland                63  Urban  2016-01-25 08:47:09   9.29   213692794373
# ...

# %%
Town_Fare=[]
for towns in List_Towns:
    Fare=Data_Index_Change.loc[towns,"fare"]
    Town_Fare.append(Fare)
Town_Fare
# Out:
# [city
#  Kelseyland     5.51
#  Kelseyland     5.54
#  Kelseyland    30.54
#  Kelseyland    12.08
#  Kelseyland    17.91
#  Kelseyland    33.56
#  Kelseyland    20.81
#  Kelseyland    44.53
#  Kelseyland    29.02
#  Kelseyland    20.05
#  Kelseyland     9.29
#  Kelseyland    20.58
#  Kelseyland    27.45
#  Kelseyland    33.51
#  Kelseyland     6.56
#  Kelseyland    20.19
#  Kelseyland    35.22
#  Kelseyland    10.31
#  Kelseyland    11.45
#  Kelseyland    27.85
#  Kelseyland     8.27
#  Kelseyland    31.67
#  Kelseyland    40.92
#  Kelseyland    12.58
#  Kelseyland    16.77
#  Kelseyland    27.21
#  Kelseyland    35.71
#  Kelseyland    15.49
#  Name: fare, dtype: float64, city
#  Kelseyland     5.51
#  Kelseyland     5.54
#  Kelseyland    30.54
#  Kelseyland    12.08
#  Kelseyland    17.91
#  Kelseyland    33.56
#  Kelseyland    20.81
#  Kelseyland    44.53
#  Kelseyland    29.02
#  Kelseyland    20.05
#  Kelseyland     9.29
#  Kelseyland    20.58
#  Kelseyland    27.45
# ...
